# %%
import os, sys
sys.path.append("..")

# %%
from utils.sequence_labeler import SequenceLabeler

# %%
BIO_labeler = SequenceLabeler(labeling_scheme='BIO',longest_labeling_flag=True)

# %%
Input = ["I", "Love", "you"]
Label = ["B", "I", "O"]

# %%
BIO_labeler.BIO_decode(Input, Label)
# Out:
# [{'entity_type': '',
#   'entity_token_span': (0, 2),
#   'start_token': 0,
#   'end_token': 2,
#   'text:': 'I Love'}]

# %%
load_ner_file("../../data/bioner/s800/test.tsv")
# Out:
# ['B', 'I', 'I', 'I', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# [{'entity_type': '', 'entity_token_span': (0, 6), 'start_token': 0, 'end_token': 6, 'text:': 'Streptococcus ursoris sp . nov .'}]
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'O']
# ...
